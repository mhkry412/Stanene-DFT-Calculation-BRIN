# %%
# Import the necessary packages and modules
import matplotlib.pyplot as plt
plt.style.use('../../matplotlib/sci.mplstyle')
import numpy as np

# The Fermi energy, find it in header row of gr.dos
efermi = -2.4054

# Open and read the file gr.dos
ener, dos, idos = np.loadtxt('sn_edos.dos', unpack=True)
    
# Create figure object
plt.figure()
# Plot the DOS, in which the Fermi energy shifts to zero
plt.plot(ener-efermi, dos, c='b')
# Add the x and y-axis labels
plt.xlabel('Energy (eV)')
plt.ylabel('DOS (state/eV/unit-cell)')
plt.axvline(x=efermi, linewidth=1, color='k', linestyle=(0, (8, 10)))
# Set the axis limits
plt.xlim(-11, 11)
plt.ylim(0, 6)
# Save the figure to the pdf file
plt.savefig('plot_sn_edos.jpg')
# Show the figure
plt.show()
